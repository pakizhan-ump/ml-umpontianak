# %% [markdown]
# <a href="https://colab.research.google.com/github/pakizhan-ump/ml-umpontianak/blob/main/Modules/Week-03/Praktikum-03/praktikum_1_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRAKTIKUM 1: SEABORN
#
# ## 🎯 Tujuan Praktikum
#
# ### **Memahami Konsep Dasar Visualisasi Data**
# - Memahami pentingnya visualisasi data dalam analisis eksploratori
# - Mengenal berbagai jenis plot dan kegunaannya
# - Mampu memilih visualisasi yang tepat untuk jenis data yang berbeda
#
# ### **Menguasai Library Seaborn**
# - Memahami kelebihan Seaborn dalam statistical plotting
# - Mampu membuat visualisasi yang lebih kompleks (violin plot, pair plot, heatmap)
# - Menggunakan tema dan color palette yang menarik
#
# ### **Aplikasi pada Real Dataset**
# - Menerapkan visualisasi pada dataset dari scikit-learn
# - Mampu mengekstrak insight dari visualisasi yang dibuat
# - Membuat laporan visual yang efektif untuk presentasi
#
# ## 📚 Dasar Teori / Pengantar
#
# ### **Seaborn**
#
# Seaborn adalah library visualisasi data Python yang dibangun di atas Matplotlib. Dibuat oleh Michael Waskom, seaborn menyediakan interface high-level untuk membuat visualisasi statistik yang menarik dan informatif.
#
# **Keunggulan Seaborn:**
# - **High-level interface** yang lebih mudah digunakan
# - **Tampilan default** yang lebih menarik
# - **Integrasi yang baik** dengan pandas DataFrames
# - **Fungsi built-in** untuk visualisasi statistik kompleks
# - **Color palette** yang lebih sophisticated
#
# ## 📖 Sumber Belajar
#
# 1. **Official Documentation:**
#    - [Matplotlib Documentation](https://matplotlib.org/stable/contents.html)
#    - [Seaborn Documentation](https://seaborn.pydata.org/)
#    - [Scikit-learn Datasets](https://scikit-learn.org/stable/datasets.html)

# %% [markdown]
# 🔧 FUNGSI UMUM SEABORN

# %%
import seaborn as sns
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# 1. Basic Seaborn Setup dan Style

# %%
print("=== SEABORN SETUP DAN STYLE ===")

# Set style seaborn
sns.set_style("whitegrid")
sns.set_palette("Spectral")
# Out:
# === SEABORN SETUP DAN STYLE ===

# %% [markdown]
# 2. Distribution Plots

# %%
print("=== DISTRIBUTION PLOTS ===")

# Create sample data
np.random.seed(42)
data = np.random.normal(0, 1, 1000)

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Histogram dengan KDE
sns.histplot(data=data, kde=True, ax=axes[0,0])
axes[0,0].set_title('Histogram dengan KDE')

# KDE Plot
sns.kdeplot(data=data, ax=axes[0,1], fill=True)
axes[0,1].set_title('KDE Plot')

# Box Plot
sns.boxplot(data=data, ax=axes[1,0])
axes[1,0].set_title('Box Plot')

# Violin Plot
sns.violinplot(data=data, ax=axes[1,1])
axes[1,1].set_title('Violin Plot')

plt.tight_layout()
plt.show()
# Out:
# === DISTRIBUTION PLOTS ===

# %% [markdown]
# 3. Categorical Plots

# %%
# Load sample dataset
tips = sns.load_dataset("tips")
print("Tips dataset shape:", tips.shape)
print("\nFirst 5 rows:")
print(tips.head())
# Out:
# Tips dataset shape: (244, 7)
#
# First 5 rows:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print("=== CATEGORICAL PLOTS ===")

fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# Bar plot
sns.barplot(data=tips, x='day', y='total_bill', ax=axes[0,0])
axes[0,0].set_title('Bar Plot - Total Bill by Day')

# Box plot
sns.boxplot(data=tips, x='day', y='total_bill', hue='sex', ax=axes[0,1])
axes[0,1].set_title('Box Plot - Total Bill by Day and Sex')

# Violin plot
sns.violinplot(data=tips, x='day', y='total_bill', hue='sex', 
               split=True, ax=axes[1,0])
axes[1,0].set_title('Violin Plot - Total Bill by Day and Sex')

# Swarm plot
sns.swarmplot(data=tips, x='day', y='total_bill', hue='sex', 
              size=3, ax=axes[1,1])
axes[1,1].set_title('Swarm Plot - Total Bill by Day and Sex')

plt.tight_layout()
plt.show()
# Out:
# === CATEGORICAL PLOTS ===

# %% [markdown]
# 4. Relational Plots

# %%
print("=== RELATIONAL PLOTS ===")

fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# Scatter plot
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='time', 
                size='size', sizes=(20, 200), ax=axes[0,0])
axes[0,0].set_title('Scatter Plot - Tip vs Total Bill')

# Line plot
sns.lineplot(data=tips, x='total_bill', y='tip', hue='day', 
             err_style='band', ax=axes[0,1])
axes[0,1].set_title('Line Plot - Tip vs Total Bill')

# Relational plot dengan regression
sns.regplot(data=tips, x='total_bill', y='tip', ax=axes[1,0])
axes[1,0].set_title('Reg Plot - Tip vs Total Bill')

# LM plot dengan hue
sns.lmplot(data=tips, x='total_bill', y='tip', hue='smoker', 
           col='time', height=5, aspect=1.2)
plt.suptitle('LM Plot - Tip vs Total Bill by Smoker and Time', y=1.02)
plt.show()
# Out:
# === RELATIONAL PLOTS ===

# %% [markdown]
# 5. Matrix Plots

# %%
# Load sample dataset
tips = sns.load_dataset("tips")
print("Tips dataset shape:", tips.shape)
print("\nFirst 5 rows:")
print(tips.head())
# Out:
# Tips dataset shape: (244, 7)
#
# First 5 rows:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# In[10]: Matrix Plots
print("=== MATRIX PLOTS ===")

# Select only numerical columns for correlation
numerical_tips = tips.select_dtypes(include=[np.number])

plt.figure(figsize=(6, 5))

# Correlation heatmap
correlation_matrix = numerical_tips.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)

plt.suptitle('Correlation Heatmap')
plt.show()

# Pair plot (akan dibuat di figure terpisah)
plt.figure(figsize=(10, 8))
sns.pairplot(tips, hue='time', diag_kind='hist', palette='viridis')
plt.suptitle('Pair Plot of Tips Dataset')
plt.show()
# Out:
# === MATRIX PLOTS ===
