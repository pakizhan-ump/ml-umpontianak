# %% [markdown]
# <a href="https://colab.research.google.com/github/pakizhan-ump/ml-umpontianak/blob/main/Modules/Week-03/Praktikum-03/praktikum_1_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRAKTIKUM 1: MATAPLOTLIB
#
# ## 🎯 Tujuan Praktikum
#
# ### **Memahami Konsep Dasar Visualisasi Data**
# - Memahami pentingnya visualisasi data dalam analisis eksploratori
# - Mengenal berbagai jenis plot dan kegunaannya
# - Mampu memilih visualisasi yang tepat untuk jenis data yang berbeda
#
# ### **Menguasai Library Matplotlib**
# - Memahami struktur figure dan axes dalam Matplotlib
# - Mampu membuat plot dasar (line, scatter, bar, histogram)
# - Mengkustomisasi tampilan visualisasi (warna, label, legend, dll.)
#
# ## 📚 Dasar Teori / Pengantar
#
# ### **Matplotlib**
#
# Matplotlib adalah library visualisasi data yang powerful dan fleksibel untuk Python. Dibuat oleh John D. Hunter, matplotlib menyediakan kemampuan untuk membuat plot statis, animasi, dan visualisasi interaktif.
#
# **Karakteristik Matplotlib:**
# - **Low-level library**, memberikan kontrol penuh atas elemen plot
# - **Mirip dengan MATLAB** dalam sintaksnya
# - **Dapat menghasilkan format output** seperti PNG, PDF, SVG, dll.
# - **Dasar dari banyak library** visualisasi Python lainnya
#
# ## 📖 Sumber Belajar
#
# 1. **Official Documentation:**
#    - [Matplotlib Documentation](https://matplotlib.org/stable/contents.html)
#    - [Seaborn Documentation](https://seaborn.pydata.org/)
#    - [Scikit-learn Datasets](https://scikit-learn.org/stable/datasets.html)

# %% [markdown]
# 🔧 FUNGSI UMUM MATPLOTLIB

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 1. Basic Plot Setup

# %%
print("=== BASIC SETUP DAN LINE PLOT ===")

# Data contoh
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='sin(x)', color='blue', linewidth=2, linestyle='-')
plt.xlabel('X Axis Label', fontsize=12)
plt.ylabel('Y Axis Label', fontsize=12)
plt.title('Basic Line Plot dengan Matplotlib', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()
# Out:
# === BASIC SETUP DAN LINE PLOT ===

# %% [markdown]
# 2. Multiple Plots dalam Satu Figure

# %%
print("=== MULTIPLE PLOTS DALAM SATU FIGURE ===")

x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x/2)

plt.figure(figsize=(12, 8))

# Plot 1
plt.subplot(2, 2, 1)  # (rows, columns, position)
plt.plot(x, y1, 'r-', label='sin(x)')
plt.title('Sine Wave')
plt.legend()

# Plot 2
plt.subplot(2, 2, 2)
plt.plot(x, y2, 'g--', label='cos(x)')
plt.title('Cosine Wave')
plt.legend()

# Plot 3
plt.subplot(2, 2, 3)
plt.plot(x, y3, 'b:', label='tan(x/2)')
plt.title('Tangent Wave')
plt.legend()

# Plot 4
plt.subplot(2, 2, 4)
plt.plot(x, y1, 'r-', label='sin(x)')
plt.plot(x, y2, 'g--', label='cos(x)')
plt.plot(x, y3, 'b:', label='tan(x/2)')
plt.title('Combined Plot')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# === MULTIPLE PLOTS DALAM SATU FIGURE ===

# %% [markdown]
# 3. Scatter Plot

# %%
print("=== SCATTER PLOT ===")

np.random.seed(42)
x = np.random.normal(0, 1, 100)
y = np.random.normal(0, 1, 100)
colors = np.random.rand(100)
sizes = 100 * np.random.rand(100)

plt.figure(figsize=(10, 6))
scatter = plt.scatter(x, y, c=colors, s=sizes, alpha=0.7, cmap='viridis')
plt.colorbar(scatter, label='Color Intensity')
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Scatter Plot dengan Color Mapping')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# === SCATTER PLOT ===

# %% [markdown]
# 4. Bar Plot dan Histogram

# %%
print("=== BAR PLOT DAN HISTOGRAM ===")

# Data untuk bar plot
categories = ['A', 'B', 'C', 'D', 'E']
values = [23, 45, 56, 12, 67]

# Data untuk histogram
data_hist = np.random.normal(0, 1, 1000)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Bar plot
ax1.bar(categories, values, color=['red', 'blue', 'green', 'orange', 'purple'])
ax1.set_title('Bar Plot Example')
ax1.set_xlabel('Categories')
ax1.set_ylabel('Values')

# Histogram
ax2.hist(data_hist, bins=30, alpha=0.7, color='skyblue', edgecolor='black')
ax2.set_title('Histogram Example')
ax2.set_xlabel('Value')
ax2.set_ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# === BAR PLOT DAN HISTOGRAM ===

# %% [markdown]
# 5. Customization Advanced

# %%
print("=== ADVANCED CUSTOMIZATION ===")

x = np.linspace(0, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.figure(figsize=(12, 6))

# Plot dengan berbagai customizations
plt.plot(x, y1, label='sin(x)', color='red', linewidth=2, 
         marker='o', markersize=4, markevery=5, alpha=0.7)
plt.plot(x, y2, label='cos(x)', color='blue', linewidth=2, 
         linestyle='--', alpha=0.7)

# Customize axes
plt.xlim(0, 2*np.pi)
plt.ylim(-1.5, 1.5)
plt.xticks([0, np.pi/2, np.pi, 3*np.pi/2, 2*np.pi], 
           ['0', 'π/2', 'π', '3π/2', '2π'])
plt.yticks([-1, -0.5, 0, 0.5, 1])

# Add grid and legend
plt.grid(True, alpha=0.3, linestyle=':')
plt.legend(loc='upper right', fontsize=12, frameon=True, fancybox=True, shadow=True)

# Add text annotation
plt.annotate('Maximum sin(x)', xy=(np.pi/2, 1), xytext=(np.pi/2 + 0.5, 0.8),
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.2'),
             fontsize=10)

plt.title('Advanced Plot Customization', fontsize=14, pad=20)
plt.xlabel('X Axis (Radians)', fontsize=12)
plt.ylabel('Y Axis (Amplitude)', fontsize=12)

plt.show()
# Out:
# === ADVANCED CUSTOMIZATION ===
